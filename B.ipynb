# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output

# %%
# %%bash
# g++ B.cpp
# ./a.out 10000 > data2.txt

# %%
a = np.genfromtxt("data2.txt")
Theta = a[:,0]
F = a[:,1]
plt.figure(figsize=(15,15))
plt.scatter(F,Theta, s=4)
plt.xlim(1.4,1.55)
plt.ylim(-3,3)
plt.xlabel('Fuerza')
plt.ylabel('$\\Theta$')
plt.savefig("BP.png")
plt.show()
